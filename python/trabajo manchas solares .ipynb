# %%
# %pylab inline
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
t=np.loadtxt(open("monthrg.dat","r"))
size=shape(t)

# %%
#plt.plot(t)
plt.xlabel('tiempo')
plt.ylabel('manchas solares')
plt.plot(t[:,3])
year=t[:,0]
month=t[:,1]
mediciones=t[:,2]
manchas=t[:,3]
desviacion=t[:,4]

# %%
from scipy.fftpack import fft, fftfreq
#se guarda el numero de mediciones
num=size[0]
dt=1

# %%
fft_x = fft(manchas) / num # FFT Normalized
freq = fftfreq(num, dt) # Recuperamos las frecuencias
plt.plot(freq,np.abs(fft_x),"k,")
print freq
#se obtiene la transfomrada
#la frecuencia esta guardad en freq
# Out:
# [ 0.          0.00021589  0.00043178 ..., -0.00064767 -0.00043178
#  -0.00021589]

# %%
posicion=0
for i in (range(num)):
    dato=manchas[i]
    if(dato==-99):
        posicion=i
        
posicion
# Out:
# 2224

# %%
M=np.empty(0)
for i in range(num-posicion):
    datos=manchas[posicion+i]
    M=np.append(M,datos)

# %%
plt.plot(M)
#se tienen los datos utiles

# %%
fft_m = fft(M) / (num-posicion) # FFT Normalized
freq = fftfreq((num-posicion), dt) # Recuperamos las frecuencias
plt.plot(freq,np.abs(fft_m),"r,")
print freq1
#se obtiene la transfomrada de los datos utiles
#la frecuencia esta guardad en freq, las frecuencias utiles
# Out:
# [ 0.          0.00041528  0.00083056 ..., -0.00124585 -0.00083056
#  -0.00041528]

# %%
plt.plot(freq,np.abs(fft_m))
datosUtiles=shape(freq)[0]
datosUtiles
# Out:
# 2408

# %%
maximo=np.abs(fft_m[1])
posicion=1
#se halla el mayor valor de amplitud del fft_m  sin contar la primera posicion que sera como un tipo de envolvente

for i in range(datosUtiles-1):
    
    if(np.abs(fft_m[i+1])>maximo ):
        
        posicion=i+1
        maximo=M[i+1]
posicion
# Out:
# 20

# %%
#se hallo el valor minimo de frecuencias de la transformada
maximo
# Out:
# 16.199999999999999

# %%
#se toma el periodo como inverso de la frecuencia
Periodo=1/freq[posicion]
Periodo
print "el periodo es",Periodo,"meses"
# Out:
# el periodo es 120.4 meses
